# %%
import pandas as pd
#create sample dataframe
df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(df)
# Out:
#      name department  salary  experience
# 0   Alice         HR   50000           2
# 1     Bob         IT   70000           5
# 2  charli         IT   70000           4
# 3   david    Finance   60000           6
# 4     Eva         HR   52000           3
# 5   Frank    Finance   60000           6

# %%
import pandas as pd
#sort by one column
sal=df.sort_values('salary',ascending=False)
df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(sal)
# Out:
#      name department  salary  experience
# 1     Bob         IT   70000           5
# 2  charli         IT   70000           4
# 5   Frank    Finance   60000           6
# 3   david    Finance   60000           6
# 4     Eva         HR   52000           3
# 0   Alice         HR   50000           2

# %%
import pandas as pd
#sort by one column
sal=df.sort_values(['salary','experience'],ascending=[False,True])
df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(sal)
# Out:
#      name department  salary  experience
# 2  charli         IT   70000           4
# 1     Bob         IT   70000           5
# 3   david    Finance   60000           6
# 5   Frank    Finance   60000           6
# 4     Eva         HR   52000           3
# 0   Alice         HR   50000           2
# None

# %%
import pandas as pd
#sort by one column
sal=df.sort_values(['salary','experience'])
df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(sal)
# Out:
#      name department  salary  experience
# 0   Alice         HR   50000           2
# 4     Eva         HR   52000           3
# 3   david    Finance   60000           6
# 5   Frank    Finance   60000           6
# 2  charli         IT   70000           4
# 1     Bob         IT   70000           5

# %%
import pandas as pd
#sort by index
sal=df.sort_index()
df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(sal)
# Out:
# department
# Finance    0.333333
# HR         0.333333
# IT         0.333333
# Name: proportion, dtype: float64

# %%
#ranking

import pandas as pd

df['rank_salary']=df['salary'].rank()

print(df)
# Out:
#      name department  salary  experience  rank_salary
# 0   Alice         HR   50000           2          1.0
# 1     Bob         IT   70000           5          5.5
# 2  charli         IT   70000           4          5.5
# 3   david    Finance   60000           6          3.5
# 4     Eva         HR   52000           3          2.0
# 5   Frank    Finance   60000           6          3.5

# %%
import pandas as pd

df['rank_salary']=df['salary'].rank(ascending=False)
print(df)
# Out:
#      name department  salary  experience  rank_salary
# 0   Alice         HR   50000           2          6.0
# 1     Bob         IT   70000           5          1.5
# 2  charli         IT   70000           4          1.5
# 3   david    Finance   60000           6          3.5
# 4     Eva         HR   52000           3          5.0
# 5   Frank    Finance   60000           6          3.5

# %%
import pandas as pd
df['dense_rank_salary']=df['salary'].rank(ascending=False,method='dense')
print(df)
# Out:
#      name department  salary  experience  dense_rank_salary
# 0   Alice         HR   50000           2                4.0
# 1     Bob         IT   70000           5                1.0
# 2  charli         IT   70000           4                1.0
# 3   david    Finance   60000           6                2.0
# 4     Eva         HR   52000           3                3.0
# 5   Frank    Finance   60000           6                2.0

# %%
#value counts examples(frequency)
df=df['department'].value_counts()
print(df)
# Out:
# department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %%
import pandas as pd
# Re-initialize df to the original DataFrame structure before proceeding,
# as df was overwritten as a Series in the previous cell.
df = pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
#proportion(percentage distribution)
df = df['department'].value_counts(normalize=True)
print(df)
# Out:
# department
# HR         0.333333
# IT         0.333333
# Finance    0.333333
# Name: proportion, dtype: float64

# %%
import pandas as pd

df=pd.DataFrame({
    'name':['Alice','Bob','charli','david','Eva','Frank'],
    'department':['HR','IT','IT','Finance','HR','Finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
#proportion(percentage distribution)
df=df['department'].value_counts(normalize=True)
print(df)
# Out:
# department
# HR         0.333333
# IT         0.333333
# Finance    0.333333
# Name: proportion, dtype: float64

# %%
#Basic plotting examples
#LINE PLOT
df[['salary','experience']].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3618728220.py in <cell line: 0>()
#       2 #LINE PLOT
#       3 df[['salary','experience']].plot()
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
df[['salary','experience']].plot()
plt.show()

# %%
import matplotlib.pyplot as plt
df.plot(kind='bar',x='name',y='salary')
plt.show()

# %%
import matplotlib.pyplot as plt
df['salary'].plot(kind='hist',bins=5)
plt.show()

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter',x='experience',y='salary')
plt.show()

# %%
import matplotlib.pyplot as plt
df[['salary','experience']].plot(kind='box')
plt.show()
