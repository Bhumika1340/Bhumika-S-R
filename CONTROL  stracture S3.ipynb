# %%
nums=[1,2,3]
for i in range(len(nums)):
  nums[i]=nums[i]+1
print(nums)
# Out:
# [2, 3, 4]

# %%
fields=[[10,0,15],[0,20,0],5,10,25]
irrigated=0
for row in range(len(fields)):
   for col in range(len(fields[row])):
      if fields[row][col]<12:
        irrigated+=1
        continue
      if fields[row][col]>20:
        break
print(irrigated)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3755720702.py in <cell line: 0>()
#       2 irrigated=0
#       3 for row in range(len(fields)):
# ----> 4    for col in range(len(fields[row])):
#       5     if fields[row][col]<12:
#       6      irrigated+=1
#
# TypeError: object of type 'int' has no len()

# %%
test_control((1,2,3,4))

def test_control(tup):
  count_even=0
  for val %2==0:
    count_even+=1
  elif value>2:
    continue
  return count_even

# %%
print(modify_inplace[10,20,30])
def modify_inplace(nums):
  i=0
  while i<len(nums):
    if nums[i]<25:
      nums[i]
