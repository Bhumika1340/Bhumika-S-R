# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2022}

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
hislist=dict(
    tfarmer_name="ramesh",
    age=45,
    village="mandya"
)
print(thislist)
# Out:
# {'farmer_name': 'ramesh', 'age': 45, 'village': 'mandya'}

# %%
thislist=dict(
    farmer_name="ramesh",
    age=45,
    village="mandya"
)
print(thislist)

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict["variety"]
print(x)
# Out:
# IR-64

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.get("variety")
print(x)
# Out:
# IR-64

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.keys()
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])

# %%
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.values()
print(x)
# Out:
# dict_values(['rice', 'IR-64', 2024])

# %%
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=farm.values()
print(x)
farm["year"]=2025
print(x)
# Out:
# dict_values(['rice', 'IR-64', 2024])
# dict_values(['rice', 'IR-64', 2025])

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.items()
print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))

thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
if"variety" in thisdict:
  print("yes","variety", "is one of the keys in the thisdict dictionary")
# Out:
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)])
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)])
# ('crop', 'variety', 'year')
# ['rice', 'IR-64', 2024]
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# yes variety is one of the keys in the thisdict dictionary

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=thisdict.items()
print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))

thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
if"variety" in thisdict:
  print("yes","variety is one of the keys in the thisdict dictionary")
# Out:
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)])
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)])
# ('crop', 'variety', 'year')
# ['rice', 'IR-64', 2024]
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# yes variety is one of the keys in the thisdict dictionary

# %%
student={
    "name":"bhumika",
    "roll_no":2040,
    "branch":"agri",
    "marks":84,
    "year":2026
}
print("original dictonary:",student)
# Out:
# original dictonary: {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri', 'marks': 84, 'year': 2026}

# %%
from typing import LiteralString
student={
    "name":"bhumika",
    "roll_no":2040,
    "branch":"agri",
    "marks":84,
    "year":2026
}
print("origal dictionery:",student)
student_copy=student.copy()
print("copied_dictionery:",student_copy)
removed_value=student.pop("marks")
print("removed value:",removed_value)
print("after pop():",student)
last_item=student.popitem()
print("last item:",last_item)
print("after popitem():",student)
student.update({"year":2,"branch":"agri"})
print("after update:",student)
student.clear()
print("after clear():",student)
del student
# Out:
# origal dictionery: {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri', 'marks': 84, 'year': 2026}
# copied_dictionery: {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri', 'marks': 84, 'year': 2026}
# removed value: 84
# after pop(): {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri', 'year': 2026}
# last item: ('year', 2026)
# after popitem(): {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri'}
# after update: {'name': 'bhumika', 'roll_no': 2040, 'branch': 'agri', 'year': 2}
# after clear(): {}
