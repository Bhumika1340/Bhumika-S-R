# %%
moisture=float(input("Enter soil moisture(%):"))
rainfall=float(input("Enter rainfall(mm):"))

if moisture>=70 and rainfall>=200:
  print("suitable for rice")
else:
  print("not suitable for rice")

# %%
moisture=float(input("Enter soil moisture(%):"))
rainfall=float(input("Enter rainfall(mm):"))

if moisture>=70 and rainfall>=200:
  print("suitable for rice")
else:
  print("not suitable for rice")

# %%
#accept inputs
moisture=float(input("70(%):"))
rainfall=float(input("200(mm):"))

#check suitability
if moisture>=70 and rainfall>=200:
  print("suitable for rice")
else:
  print("not suitable for rice")

# %%
soil_moisture=65
rainfall=150mm
 if soil_moisture>=70 and rainfall>=200:
   print("suitable for rice")
else:
  print("not suitable for rice")

# %%
print("\n ===if else===")
soil_moisture=65
rainfall=150mm
 if soil_moisture>=70 and rainfall>=200:
   print("suitable for rice")
else:
  print("not suitable for rice")
