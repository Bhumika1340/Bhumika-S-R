# %%
import numpy as np
a=np.array([[1,2],[3,4],[5,6]])
a[a[:,1]%2==0]
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
import numpy as np
a=np.array([[1,2],[3,4],[5,6]])
a[a%2==0]
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
mask=np.array([True,False,True,False,True,False])
print(a[mask]*10)
# Out:
# [10 30 50]

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
b=np.array([10,20,30])
print(a+b.shape)
# Out:
# [[4 5 6]
#  [7 8 9]]

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
b=np.array([10,20,30])
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-456334632.py in <cell line: 0>()
#       2 a=np.array([[1,2],[3,4]])
#       3 b=np.array([10,20,30])
# ----> 4 print(a+b)
#
# ValueError: operands could not be broadcast together with shapes (2,2) (3,)

# %%
import numpy as np
x=np.array(10)
x[x%2==0]*=2
print(x)
# Out:
# 20

# %%
import numpy as np
a=np.array([[1,2],[3,4],[5,6]])
mask=np.array([False,False,False])
print(a[mask])
# Out:
# []

# %%
import numpy as np
a=np.array((2,3))
b=np.array((3,))
print(a*b)
# Out:
# [6 9]

# %%
import numpy as np
import builtins
a=np.array([10,20,30,40,50])
idx=np.array([4,0,4,1])
builtins.print(a[idx])
# Out:
# [50 10 50 20]

# %%
import numpy as np

a=np.array([10,20,30,40,50])
idx=np.array([4,0,4,1])
print(a[idx])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1725448869.py in <cell line: 0>()
#       3 a=np.array([10,20,30,40,50])
#       4 idx=np.array([4,0,4,1])
# ----> 5 print(a[idx])
#
# TypeError: 'numpy.ndarray' object is not callable
