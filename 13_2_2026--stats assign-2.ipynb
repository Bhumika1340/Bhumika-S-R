# %%
def get_rainfall_input():
  rainfall_list=[]
  number_of_months=int(input("Enter the number of months: "))
  for i in range(number_of_months):
    rainfall_value=int(input("Enter rainfall of the month:"))
    rainfall_list.append(rainfall_value)
  return rainfall_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# Enter the number of months: 12
# Enter rainfall of the month:50
# Enter rainfall of the month:55
# Enter rainfall of the month:60
# Enter rainfall of the month:65
# Enter rainfall of the month:70
# Enter rainfall of the month:100
# Enter rainfall of the month:150
# Enter rainfall of the month:200
# Enter rainfall of the month:300
# Enter rainfall of the month:350
# Enter rainfall of the month:400
# Enter rainfall of the month:450
# [50, 55, 60, 65, 70, 100, 150, 200, 300, 350, 400, 450]
# Enter the lots of yields: 12
# Enter the yield of the month:80
# Enter the yield of the month:100
# Enter the yield of the month:150
# Enter the yield of the month:200
# Enter the yield of the month:250
# Enter the yield of the month:1000
# Enter the yield of the month:2000
# Enter the yield of the month:3500
# Enter the yield of the month:4000
# Enter the yield of the month:100
# Enter the yield of the month:150
# Enter the yield of the month:80
# [80, 100, 150, 200, 250, 1000, 2000, 3500, 4000, 100, 150, 80]
# ===RAINFAll STATISTICS===
# Mean:187.50mm
# Median:125.00mm
# Std Dev:142.56mm
# Variance:20322.92mm
# Min:50mm(Month1)
# Max:450mm(Month12)
# Range:400mm
#
# ===YIELD STATISTICS===
# Mean:967.50tons/ha
# Median:175.00tons/ha
# Std Dev:1360.07tons/ha
#
# ===PERCENTILES===
# 25th percentile rainfall:63.75mm
# 50th percentile rainfall:125.00mm
# 75th percentile rainfall:312.50mm
# 90th percentile rainfall:395.00mm
#
# ===CORRELATION ANALYSIS===
# Rainfall_Yield Correlation:0.1303
# Weak correlation
#
# ===CUMULATIVE RAINFALL===
# Month	Rainfall	Cumulative
# 1	50		50
# 2	55		105
# 3	60		165
# 4	65		230
# 5	70		300
# 6	100		400
# 7	150		550
# 8	200		750
# 9	300		1050
# 10	350		1400
# 11	400		1800
# 12	450		2250

# %%
def get_rainfall_input():
  rainfall_list=[]
  number_of_months=int(input("Enter the number of months: "))
  for i in range(number_of_months):
    rainfall_value=int(input("Enter rainfall of the month:"))
    rainfall_list.append(rainfall_value)
  return rainfall_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')

import numpy as np
import matplotlib.pyplot as plt
x_coords=(rainfall)
y_cords=(yields) # Changed yield_data to yields
plt.plot(x_coords,y_cords)
plt.xlabel("rainfall(in mm)") # Changed plot.xlabel to plt.xlabel
plt.ylabel("yield(in tons/ha)") # Changed plot.ylabel to plt.ylabel and fixed escape sequence
plt.show() # Changed plot.show() to plt.show()
print("\ncorrelation analysis") # Fixed escape sequence
# Out:
# <>:66: SyntaxWarning: invalid escape sequence '\h'
# <>:68: SyntaxWarning: invalid escape sequence '\ '
# <>:66: SyntaxWarning: invalid escape sequence '\h'
# <>:68: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-1425282619.py:66: SyntaxWarning: invalid escape sequence '\h'
#   plot.ylabel("yield(in tons\ha)")
# /tmp/ipython-input-1425282619.py:68: SyntaxWarning: invalid escape sequence '\ '
#   print("\ correlation analysis")
# Enter the number of months: 12
# Enter rainfall of the month:50
# Enter rainfall of the month:55
# Enter rainfall of the month:60
# Enter rainfall of the month:65
# Enter rainfall of the month:70
# Enter rainfall of the month:80
# Enter rainfall of the month:100
# Enter rainfall of the month:150
# Enter rainfall of the month:200
# Enter rainfall of the month:580
# Enter rainfall of the month:300
# Enter rainfall of the month:350
# [50, 55, 60, 65, 70, 80, 100, 150, 200, 580, 300, 350]
# Enter the lots of yields: 12
# Enter the yield of the month:80
# Enter the yield of the month:100
# Enter the yield of the month:150
# Enter the yield of the month:200
# Enter the yield of the month:250
# Enter the yield of the month:170
# Enter the yield of the month:1000
# Enter the yield of the month:1500
# Enter the yield of the month:2000
# Enter the yield of the month:3000
# Enter the yield of the month:4000
# Enter the yield of the month:200
# [80, 100, 150, 200, 250, 170, 1000, 1500, 2000, 3000, 4000, 200]
# ===RAINFAll STATISTICS===
# Mean:171.67mm
# Median:90.00mm
# Std Dev:156.10mm
# Variance:24368.06mm
# Min:50mm(Month1)
# Max:580mm(Month10)
# Range:530mm
#
# ===YIELD STATISTICS===
# Mean:1054.17tons/ha
# Median:225.00tons/ha
# Std Dev:1262.44tons/ha
#
# ===PERCENTILES===
# 25th percentile rainfall:63.75mm
# 50th percentile rainfall:90.00mm
# 75th percentile rainfall:225.00mm
# 90th percentile rainfall:345.00mm
#
# ===CORRELATION ANALYSIS===
# Rainfall_Yield Correlation:0.6876
# Moderate correlation
#
# ===CUMULATIVE RAINFALL===
# Month	Rainfall	Cumulative
# 1	50		50
# 2	55		105
# 3	60		165
# 4	65		230
# 5	70		300
# 6	80		380
# 7	100		480
# 8	150		630
# 9	200		830
# 10	580		1410
# 11	300		1710
# 12	350		2060
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1425282619.py in <cell line: 0>()
#      61 import matplotlib.pyplot as plt
#      62 x_coords=(rainfall)
# ---> 63 y_cords=(yield_data)
#      64 plt.plot(x_coords,y_cords)
#      65 plot.xlabel("rainfall(in mm)")
#
# NameError: name 'yield_data' is not defined

# %%
def get_rainfall_input():
  rainfall_list=[]
  number_of_months=int(input("Enter the number of months: "))
  for i in range(number_of_months):
    rainfall_value=int(input("Enter rainfall of the month:"))
    rainfall_list.append(rainfall_value)
  return rainfall_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')

# %%
def get_rainfall_input():
  rainfall_list=[]
  number_of_months=int(input("Enter the number of months: "))
  for i in range(number_of_months):
    rainfall_value=int(input("Enter rainfall of the month:"))
    rainfall_list.append(rainfall_value)
  return rainfall_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# Enter the number of months: 5
# Enter rainfall of the month:20
# Enter rainfall of the month:30
# Enter rainfall of the month:35
# Enter rainfall of the month:40
# Enter rainfall of the month:50
# [20, 30, 35, 40, 50]
# Enter the lots of yields: 5
# Enter the yield of the month:50
# Enter the yield of the month:70
# Enter the yield of the month:80
# Enter the yield of the month:90
# Enter the yield of the month:100
# [50, 70, 80, 90, 100]
# ===RAINFAll STATISTICS===
# Mean:35.00mm
# Median:35.00mm
# Std Dev:10.00mm
# Variance:100.00mm
# Min:20mm(Month1)
# Max:50mm(Month5)
# Range:30mm
#
# ===YIELD STATISTICS===
# Mean:78.00tons/ha
# Median:80.00tons/ha
# Std Dev:17.20tons/ha
#
# ===PERCENTILES===
# 25th percentile rainfall:30.00mm
# 50th percentile rainfall:35.00mm
# 75th percentile rainfall:40.00mm
# 90th percentile rainfall:46.00mm
#
# ===CORRELATION ANALYSIS===
# Rainfall_Yield Correlation:0.9881
# Interpretation:strong positive correlation
#
# ===CUMULATIVE RAINFALL===
# Month	Rainfall	Cumulative
# 1	20		20
# 2	30		50
# 3	35		85
# 4	40		125
# 5	50		175

# %%
marks=[78,85,90,88,92]
average=sum(marks)/len(marks)
percentage=(((sum(marks))/(len(marks))*100))*100
print("average:",average)
print("percentage:",percentage)
# Out:
# average: 86.6
# percentage: 866000.0

# %%
data=[5,9,3,7,12]
mimimum=min(data)
maximum=max(data)
range_value=maximum-mimimum
print("min:",mimimum)
print("max:",maximum)
print("range:",range_value)
# Out:
# min: 3
# max: 12
# range: 9

# %%
def get_rainfall_input():
  rainfall_list=[]
  number_of_months=int(input("Enter the number of months: "))
  for i in range(number_of_months):
    rainfall_value=int(input("Enter rainfall of the month:"))
    rainfall_list.append(rainfall_value)
  return rainfall_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')

# %%
def fertilizer_input():
 fertilizer_list=[]
number_of_months=int(input("Enter the number of months: "))
for i in range(number_of_months):
    fertilizer_value=int(input("Enter fertilizer of the month:"))
    fertilizer_list.append(fertilizer_value)
  return fertilizer_list

rainfall = get_rainfall_input()
print(rainfall)

def get_yield_input():
  yields_list=[]
  total_yields=int(input("Enter the lots of yields: "))
  for i in range(total_yields):
    yield_value=int(input("Enter the yield of the month:"))
    yields_list.append(yield_value)
  return yields_list

yields = get_yield_input()
print(yields)

import numpy as np

rainfall_arr=np.array(rainfall)
yields_arr=np.array(yields)

print('===RAINFAll STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n===YIELD STATISTICS===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip (percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall_Yield Correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation'if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
