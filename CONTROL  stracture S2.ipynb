# %%
x=10
y=x
x=5
print(y)
# Out:
# 10

# %%
n=-3
if n>=0:
  if n==0:
    print("zero")
  else:
    print("positive")
else:
  print("negative")
# Out:
# negative

# %%
nums=[3,6,9,12]
total=0
for n in nums:
  total+=n
print(total)
# Out:
# 30

# %%
nums[1,2,3,4,5]
i=0
while

# %%
nums=[1,2,3,4,5]
i=0
while i<len(nums):
 if nums[i]%2==0:
    nums.pop(i)
 else:
    i+=1
print(nums)
# Out:
# [1, 3, 5]

# %%
x=5
for i in range(1,4):
  x=x^i
print(x)
# Out:
# 5

# %%
lst=[1,2,3,4]
for x in lst:
  if x%2==0:
    lst.remove(x)
print(lst)
# Out:
# [1, 3]

# %%
print(4<<2)
# Out:
# 16

# %%
lst=[1,2,3,4]
for x in lst:
  if x%2==0:
    lst.remove(x)
print(lst)
# Out:
# [1, 3]

# %%
lst1=[]
nums=[5,10,15]
for n in nums:
  n+=5
  lst1.append(n)
print(nums)
print(lst1)
# Out:
# [5, 10, 15]
# [10, 15, 20]

# %%
x=10
y=x
x=5
print(y)
# Out:
# 10

# %%
nums=[1,2,3,4]
for i in range(len(nums)):
  nums[i]*=2
print(nums)
# Out:
# [2, 4, 6, 8]

# %%
nums[1,2,3,4]
for n in nums:
 squares.append(n**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2516705059.py in <cell line: 0>()
# ----> 1 nums[1,2,3,4]
#       2 for n in nums:
#       3  squares.append(n**2)
#
# TypeError: list indices must be integers or slices, not tuple
