# %%
#S1=import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

#S2=create sample agricultural dataset
data={
    "Rainfall":[450,520,390,610,480,530,410,590],
    "Temperature":[22,20,25,19,23,21,24,18],
    "Nitrogen":[0.8,1.0,0.6,1.2,0.9,1.1,0.7,1.3],
    "Fertilizer":[120,140,100,160,130,150,110,170],
    "Yield":[3.5,4.2,2.9,4.8,3.8,4.4,3.1,5.0]

}
df=pd.DataFrame(data)

#S3=define features
x=df[["Rainfall","Temperature","Nitrogen","Fertilizer"]]
y=df["Yield"]

print(x)
print(y)

#S4=split data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train)
print(x_test)

#S5=train model
model=LinearRegression()
model.fit(x_train,y_train)

#S6=make predictons
y_pred=model.predict(x_test)

#S7=evalute model
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print("Mean Absolute Error:",round(mae,2))
print("R2-Score:",round(r2,2))

#S8=predict yield for new farm conditions
new_data=np.array([[500,21,1.0,145]]) #Rainfall,Temp,Nitogen,Fertilizer
predict_yield=model.predict(new_data)

print("predicted yield(tons/hectare)")
round(predict_yield[0],2)
# Out:
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 0       450           22       0.8         120
# 1       520           20       1.0         140
# 2       390           25       0.6         100
# 3       610           19       1.2         160
# 4       480           23       0.9         130
# 5       530           21       1.1         150
# 6       410           24       0.7         110
# 7       590           18       1.3         170
# 0    3.5
# 1    4.2
# 2    2.9
# 3    4.8
# 4    3.8
# 5    4.4
# 6    3.1
# 7    5.0
# Name: Yield, dtype: float64
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 0       450           22       0.8         120
# 7       590           18       1.3         170
# 2       390           25       0.6         100
# 4       480           23       0.9         130
# 3       610           19       1.2         160
# 6       410           24       0.7         110
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 1       520           20       1.0         140
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Rainfall', y='Yield', data=df)
plt.title('Relationship between Rainfall and Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (tons/hectare)')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

data={
    "Rainfall":[450,520,390,610,480,530,410,590],
    "Temperature":[22,20,25,19,23,21,24,18],
    "Nitrogen":[0.8,1.0,0.6,1.2,0.9,1.1,0.7,1.3],
    "Fertilizer":[120,140,100,160,130,150,110,170],
    "Yield":[3.5,4.2,2.9,4.8,3.8,4.4,3.1,5.0]

}
df=pd.DataFrame(data)

x=df[["Rainfall","Temperature","Nitrogen","Fertilizer"]]
y=df["Yield"]
print(x)
print(y)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train)
print(x_test)

model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)

mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Absolute Error:",round(mae,2))
print("R2-Score:",round(r2,2))

# Convert new_data to a DataFrame with appropriate column names to avoid the UserWarning
new_data_df = pd.DataFrame(new_data, columns=x.columns)
predict_yield=model.predict(new_data_df)

print("predicted yield(tons/hectare)")
round(predict_yield[0],2)
# Out:
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 0       450           22       0.8         120
# 1       520           20       1.0         140
# 2       390           25       0.6         100
# 3       610           19       1.2         160
# 4       480           23       0.9         130
# 5       530           21       1.1         150
# 6       410           24       0.7         110
# 7       590           18       1.3         170
# 0    3.5
# 1    4.2
# 2    2.9
# 3    4.8
# 4    3.8
# 5    4.4
# 6    3.1
# 7    5.0
# Name: Yield, dtype: float64
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 0       450           22       0.8         120
# 7       590           18       1.3         170
# 2       390           25       0.6         100
# 4       480           23       0.9         130
# 3       610           19       1.2         160
# 6       410           24       0.7         110
#    Rainfall  Temperature  Nitrogen  Fertilizer
# 1       520           20       1.0         140
# ...
