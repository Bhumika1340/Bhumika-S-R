# %%
import pandas as pd
mydataset={
      'cars':["BMW","volvo","ford"],
      'passings':[3,7,2]
  }
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  volvo         7
# 2   ford         2

# %%
import pandas as pd
mydataset={
      'cars':["BMW","volvo","ford"],
      'passings':[3,7,2]
  }

print(mydataset)
# Out:
# {'cars': ['BMW', 'volvo', 'ford'], 'passings': [3, 7, 2]}

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
a=[1,7,2]
print(a)
# Out:
# [1, 7, 2]

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(myvar[0])
# Out:
# 1

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["0","1","2"])
print(myvar)
print(myvar["1"])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 7

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["100","200","300"])
print(myvar)
print(myvar["200"])
# Out:
# 100    1
# 200    7
# 300    2
# dtype: int64
# 7

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
for val in s:
  print(val)
# Out:
# 10
# 80
# 30
# 40
# 50
# 60

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
myvar=pd.Series(s,index=["100","200","300"])
print(s)
# Out:
# 0    10
# 1    80
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
for idx,val in s.items():
  print(idx,val)
# Out:
# 0 10
# 1 80
# 2 30
# 3 40
# 4 50
# 5 60

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
print(idx,val)
# Out:
# 5 60

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
print(s)
# Out:
# 0    10
# 1    80
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
for label,val in s.items():
  print(label,val)
# Out:
# 0 10
# 1 80
# 2 30
# 3 40
# 4 50
# 5 60

# %%
import pandas as pd
s=pd.Series([100,200,300],index=['a','b','c'])
print(s)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
import pandas as pd
s=pd.Series([100,200,300],index=['a','b','c'])
for label,val in s.items():
  print(label,val)
# Out:
# a 100
# b 200
# c 300

# %%
import pandas as pd
s=pd.Series([100,200,300],index=['a10','b20','c30'])
for label,val in s.items():
  print(label)
# Out:
# a10
# b20
# c30

# %%
import pandas as pd
s=pd.Series([100,200,300],index=['a','b','c'])
for label,val in s.items():
  print(val)
# Out:
# 100
# 200
# 300

# %%
import pandas as pd
s=pd.Series([10,80,30,40,50,60])
for label,val in s.items():
  print(label,val)
# Out:
# 0 10
# 1 80
# 2 30
# 3 40
# 4 50
# 5 60

# %%
import pandas as pd
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
